# %% [markdown]
# # Create metadata
#
# This notebook creates a metadata.json file based on the EnergyPlus eplusout.csv file.

# %% [markdown]
# ## Setup

# %%
import requests
import csv
import json

# %% [markdown]
# ## Get csv file from figshare

# %%
csv_download_url='https://figshare.com/ndownloader/files/35934071?private_link=464885898d0041bfa8fd'
response=requests.get(csv_download_url)
csv_text=response.text
csv_text.split('\n')[0]
# Out:
# 'Date/Time,Environment:Site Outdoor Air Drybulb Temperature [C](Hourly),Environment:Site Total Sky Cover [](Hourly),Environment:Site Opaque Sky Cover [](Hourly),Environment:Site Daylight Saving Time Status [](Daily),Environment:Site Day Type Index [](Daily),ZONE ONE:Zone Total Internal Latent Gain Energy [J](Hourly),TEST 352A:Other Equipment Total Heating Energy [J](Monthly),TEST 352 MINUS:Other Equipment Total Heating Energy [J](Monthly),ZONE ONE:Zone Other Equipment Total Heating Energy [J](Monthly),ZONE ONE:Zone Mean Radiant Temperature [C](Hourly),ZN001:WALL001:Surface Inside Face Temperature [C](Daily),ZN001:WALL001:Surface Outside Face Temperature [C](Daily),ZN001:WALL001:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily),ZN001:WALL001:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily),ZN001:WALL002:Surface Inside Face Temperature [C](Daily),ZN001:WALL002:Surface Outside Face Temperature [C](Daily),ZN001:WALL002:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily),ZN001:WALL002:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily),ZN001:WALL003:Surface Inside Face Temperature [C](Daily),ZN001:WALL003:Surface Outside Face Temperature [C](Daily),ZN001:WALL003:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily),ZN001:WALL003:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily),ZN001:WALL004:Surface Inside Face Temperature [C](Daily),ZN001:WALL004:Surface Outside Face Temperature [C](Daily),ZN001:WALL004:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily),ZN001:WALL004:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily),ZN001:FLR001:Surface Inside Face Temperature [C](Daily),ZN001:FLR001:Surface Outside Face Temperature [C](Daily),ZN001:FLR001:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily),ZN001:ROOF001:Surface Inside Face Temperature [C](Daily),ZN001:ROOF001:Surface Outside Face Temperature [C](Daily),ZN001:ROOF001:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily),ZN001:ROOF001:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily),ZONE ONE:Zone Mean Air Temperature [C](Hourly),ZONE ONE:Zone Air Heat Balance Surface Convection Rate [W](Hourly),ZONE ONE:Zone Air Heat Balance Air Energy Storage Rate [W](Hourly) \r'

# %% [markdown]
# ## Get header row

# %%
csv_reader=csv.reader(csv_text.splitlines())
header_row=next(csv_reader)
header_row=[x.strip() for x in header_row]
header_row
# Out:
# ['Date/Time',
#  'Environment:Site Outdoor Air Drybulb Temperature [C](Hourly)',
#  'Environment:Site Total Sky Cover [](Hourly)',
#  'Environment:Site Opaque Sky Cover [](Hourly)',
#  'Environment:Site Daylight Saving Time Status [](Daily)',
#  'Environment:Site Day Type Index [](Daily)',
#  'ZONE ONE:Zone Total Internal Latent Gain Energy [J](Hourly)',
#  'TEST 352A:Other Equipment Total Heating Energy [J](Monthly)',
#  'TEST 352 MINUS:Other Equipment Total Heating Energy [J](Monthly)',
#  'ZONE ONE:Zone Other Equipment Total Heating Energy [J](Monthly)',
#  'ZONE ONE:Zone Mean Radiant Temperature [C](Hourly)',
#  'ZN001:WALL001:Surface Inside Face Temperature [C](Daily)',
#  'ZN001:WALL001:Surface Outside Face Temperature [C](Daily)',
#  'ZN001:WALL001:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#  'ZN001:WALL001:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#  'ZN001:WALL002:Surface Inside Face Temperature [C](Daily)',
#  'ZN001:WALL002:Surface Outside Face Temperature [C](Daily)',
#  'ZN001:WALL002:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#  'ZN001:WALL002:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#  'ZN001:WALL003:Surface Inside Face Temperature [C](Daily)',
#  'ZN001:WALL003:Surface Outside Face Temperature [C](Daily)',
#  'ZN001:WALL003:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#  'ZN001:WALL003:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#  'ZN001:WALL004:Surface Inside Face Temperature [C](Daily)',
#  'ZN001:WALL004:Surface Outside Face Temperature [C](Daily)',
#  'ZN001:WALL004:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#  'ZN001:WALL004:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#  'ZN001:FLR001:Surface Inside Face Temperature [C](Daily)',
#  'ZN001:FLR001:Surface Outside Face Temperature [C](Daily)',
#  'ZN001:FLR001:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#  'ZN001:ROOF001:Surface Inside Face Temperature [C](Daily)',
#  'ZN001:ROOF001:Surface Outside Face Temperature [C](Daily)',
#  'ZN001:ROOF001:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#  'ZN001:ROOF001:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#  'ZONE ONE:Zone Mean Air Temperature [C](Hourly)',
#  'ZONE ONE:Zone Air Heat Balance Surface Convection Rate [W](Hourly)',
#  'ZONE ONE:Zone Air Heat Balance Air Energy Storage Rate [W](Hourly)']

# %% [markdown]
# ## Function to create column descriptions

# %%
base_url=r"https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/"
reference_dict={
    "Site Outdoor Air Drybulb Temperature": \
        "group-location-climate-weather-file-access.html#site-outdoor-air-drybulb-temperature-c",
    "Zone Mean Radiant Temperature": \
        "group-thermal-zone-description-geometry.html#zone-mean-radiant-temperature-c-1",
    "Site Total Sky Cover": \
        "group-location-climate-weather-file-access.html#site-total-sky-cover",
    "Site Opaque Sky Cover": \
        "group-location-climate-weather-file-access.html#site-opaque-sky-cover",
    "Zone Mean Air Temperature": \
        "group-thermal-zone-description-geometry.html#zone-mean-air-temperature-c-1",
    "Zone Air Heat Balance Surface Convection Rate": \
        "group-thermal-zone-description-geometry.html#zone-air-heat-balance-surface-convection-rate-w",
    "Zone Air Heat Balance Air Energy Storage Rate": \
        "group-thermal-zone-description-geometry.html#zone-air-heat-balance-air-energy-storage-rate-w",
    "Site Daylight Saving Time Status": \
        "group-location-climate-weather-file-access.html#site-daylight-saving-time-status",
    "Site Day Type Index": \
        "group-location-climate-weather-file-access.html#site-day-type-index",
    "Zone Total Internal Latent Gain Energy": \
        "group-thermal-zone-description-geometry.html#zone-total-internal-latent-gain-energy-j",
    "Other Equipment Total Heating Energy": \
        "group-internal-gains-people-lights-other.html#outputs-5-004",
    "Surface Inside Face Temperature": \
        "group-thermal-zone-description-geometry.html#surface-inside-face-temperature-c",
    "Surface Outside Face Temperature": \
        "group-thermal-zone-description-geometry.html#surface-outside-face-temperature-c",
    "Surface Inside Face Convection Heat Transfer Coefficient": \
        "group-thermal-zone-description-geometry.html#surface-inside-face-convection-heat-transfer-coefficient-wm2-k",
    "Surface Outside Face Convection Heat Transfer Coefficient": \
        "group-thermal-zone-description-geometry.html#surface-outside-face-convection-heat-transfer-coefficient-wm2-k"
}

qudt_dict={
    #"": "http://qudt.org/vocab/unit/FRACTION",
    "C": "http://qudt.org/vocab/unit/DEG_C",
    "W": "http://qudt.org/vocab/unit/W-PER-M",
    "J": "http://qudt.org/vocab/unit/J",
    "W/m2-K": "http://qudt.org/vocab/unit/W-PER-M2-K"
}


time_interval_dict={
    "Hourly": "H1",
    "Daily": "D1",
    "Monthly": "M1"    
}


def create_column_description(header):
    ""
    d={
        "@type": "Column",
        "titles": header,
    }
    
    variable=header.split('[')[0].strip()
    
    try:
        units=header.split('[')[1].split(']')[0].strip()
    except IndexError:
        units=None
        
    try:
        time_interval=header.split('(')[1].split(')')[0].strip()
    except IndexError:
        time_interval=None
    
    # dc:description
    d["dc:description"]= header
    
    # schema:variableMeasured
    d['schema:variableMeasured']=variable
    
    # schema:unitText
    if units:
        d['schema:unitText']=units
        
    # schema:duration
    if time_interval:
        d['schema:duration']=time_interval_dict[time_interval]
    
    # dc:reference
    reference_url=None
    for k,v in reference_dict.items():
        if variable.endswith(k):
            reference_url=v
    if reference_url:
        d['dc:references']={"@id":f"{base_url}{reference_url}"}
    else:
        if not variable is None:
            print(variable)
        
    # http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure
    qudt_url=qudt_dict.get(units,None)
    if qudt_url:
        d['http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure']={"@id":f"{qudt_url}"}
    else:
        print(units)
    
    # datatype
    if variable=='Date/Time':
        d['datatype']='string'
    else:
        d['datatype']='number'
        
    # other comments
    if variable=='Date/Time':
        d['rdfs:comment']='The Date/Time column contains a non-standard date and time format which does match any of the CSVW data format options.'
        
    return d

# test below
header='Environment:Site Outdoor Air Drybulb Temperature [C](Hourly)'
create_column_description(header)
# Out:
# {'@type': 'Column',
#  'titles': 'Environment:Site Outdoor Air Drybulb Temperature [C](Hourly)',
#  'dc:description': 'Environment:Site Outdoor Air Drybulb Temperature [C](Hourly)',
#  'schema:variableMeasured': 'Environment:Site Outdoor Air Drybulb Temperature',
#  'schema:unitText': 'C',
#  'schema:duration': 'H1',
#  'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-location-climate-weather-file-access.html#site-outdoor-air-drybulb-temperature-c'},
#  'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#  'datatype': 'number'}

# %% [markdown]
# ## Create & save metadata dict

# %%
d={
    "@context": "http://www.w3.org/ns/csvw",
    "@type": "Table",
    "url": "eplusout.csv",
    "dc:title": "EnergyPlus simulation test",
    "dc:description": "An EnergyPlus simulation of an office room in Sir Frank Gibb building, Loughborough University",
    "dc:creator": "ABCE Open Research Team",   
    "tableSchema": {
        "@type": "Schema",
        "columns": [create_column_description(header) for header in header_row]
        }
}
with open('eplusout.csv-metadata.json','w') as f:
    json.dump(d, f, indent=4)
d
# Out:
# Date/Time
# None
# {'@context': 'http://www.w3.org/ns/csvw',
#  '@type': 'Table',
#  'url': 'eplusout.csv',
#  'dc:title': 'EnergyPlus simulation test',
#  'dc:description': 'An EnergyPlus simulation of an office room in Sir Frank Gibb building, Loughborough University',
#  'dc:creator': 'ABCE Open Research Team',
#  'tableSchema': {'@type': 'Schema',
#   'columns': [{'@type': 'Column',
#     'titles': 'Date/Time',
#     'dc:description': 'Date/Time',
#     'schema:variableMeasured': 'Date/Time',
#     'datatype': 'string',
#     'rdfs:comment': 'The Date/Time column contains a non-standard date and time format which does match any of the CSVW data format options.'},
#    {'@type': 'Column',
#     'titles': 'Environment:Site Outdoor Air Drybulb Temperature [C](Hourly)',
#     'dc:description': 'Environment:Site Outdoor Air Drybulb Temperature [C](Hourly)',
#     'schema:variableMeasured': 'Environment:Site Outdoor Air Drybulb Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'H1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-location-climate-weather-file-access.html#site-outdoor-air-drybulb-temperature-c'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'Environment:Site Total Sky Cover [](Hourly)',
#     'dc:description': 'Environment:Site Total Sky Cover [](Hourly)',
#     'schema:variableMeasured': 'Environment:Site Total Sky Cover',
#     'schema:duration': 'H1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-location-climate-weather-file-access.html#site-total-sky-cover'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'Environment:Site Opaque Sky Cover [](Hourly)',
#     'dc:description': 'Environment:Site Opaque Sky Cover [](Hourly)',
#     'schema:variableMeasured': 'Environment:Site Opaque Sky Cover',
#     'schema:duration': 'H1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-location-climate-weather-file-access.html#site-opaque-sky-cover'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'Environment:Site Daylight Saving Time Status [](Daily)',
#     'dc:description': 'Environment:Site Daylight Saving Time Status [](Daily)',
#     'schema:variableMeasured': 'Environment:Site Daylight Saving Time Status',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-location-climate-weather-file-access.html#site-daylight-saving-time-status'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'Environment:Site Day Type Index [](Daily)',
#     'dc:description': 'Environment:Site Day Type Index [](Daily)',
#     'schema:variableMeasured': 'Environment:Site Day Type Index',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-location-climate-weather-file-access.html#site-day-type-index'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZONE ONE:Zone Total Internal Latent Gain Energy [J](Hourly)',
#     'dc:description': 'ZONE ONE:Zone Total Internal Latent Gain Energy [J](Hourly)',
#     'schema:variableMeasured': 'ZONE ONE:Zone Total Internal Latent Gain Energy',
#     'schema:unitText': 'J',
#     'schema:duration': 'H1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#zone-total-internal-latent-gain-energy-j'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/J'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'TEST 352A:Other Equipment Total Heating Energy [J](Monthly)',
#     'dc:description': 'TEST 352A:Other Equipment Total Heating Energy [J](Monthly)',
#     'schema:variableMeasured': 'TEST 352A:Other Equipment Total Heating Energy',
#     'schema:unitText': 'J',
#     'schema:duration': 'M1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-internal-gains-people-lights-other.html#outputs-5-004'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/J'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'TEST 352 MINUS:Other Equipment Total Heating Energy [J](Monthly)',
#     'dc:description': 'TEST 352 MINUS:Other Equipment Total Heating Energy [J](Monthly)',
#     'schema:variableMeasured': 'TEST 352 MINUS:Other Equipment Total Heating Energy',
#     'schema:unitText': 'J',
#     'schema:duration': 'M1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-internal-gains-people-lights-other.html#outputs-5-004'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/J'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZONE ONE:Zone Other Equipment Total Heating Energy [J](Monthly)',
#     'dc:description': 'ZONE ONE:Zone Other Equipment Total Heating Energy [J](Monthly)',
#     'schema:variableMeasured': 'ZONE ONE:Zone Other Equipment Total Heating Energy',
#     'schema:unitText': 'J',
#     'schema:duration': 'M1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-internal-gains-people-lights-other.html#outputs-5-004'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/J'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZONE ONE:Zone Mean Radiant Temperature [C](Hourly)',
#     'dc:description': 'ZONE ONE:Zone Mean Radiant Temperature [C](Hourly)',
#     'schema:variableMeasured': 'ZONE ONE:Zone Mean Radiant Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'H1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#zone-mean-radiant-temperature-c-1'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL001:Surface Inside Face Temperature [C](Daily)',
#     'dc:description': 'ZN001:WALL001:Surface Inside Face Temperature [C](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL001:Surface Inside Face Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-inside-face-temperature-c'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL001:Surface Outside Face Temperature [C](Daily)',
#     'dc:description': 'ZN001:WALL001:Surface Outside Face Temperature [C](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL001:Surface Outside Face Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-outside-face-temperature-c'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL001:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'dc:description': 'ZN001:WALL001:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL001:Surface Inside Face Convection Heat Transfer Coefficient',
#     'schema:unitText': 'W/m2-K',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-inside-face-convection-heat-transfer-coefficient-wm2-k'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/W-PER-M2-K'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL001:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'dc:description': 'ZN001:WALL001:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL001:Surface Outside Face Convection Heat Transfer Coefficient',
#     'schema:unitText': 'W/m2-K',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-outside-face-convection-heat-transfer-coefficient-wm2-k'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/W-PER-M2-K'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL002:Surface Inside Face Temperature [C](Daily)',
#     'dc:description': 'ZN001:WALL002:Surface Inside Face Temperature [C](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL002:Surface Inside Face Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-inside-face-temperature-c'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL002:Surface Outside Face Temperature [C](Daily)',
#     'dc:description': 'ZN001:WALL002:Surface Outside Face Temperature [C](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL002:Surface Outside Face Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-outside-face-temperature-c'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL002:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'dc:description': 'ZN001:WALL002:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL002:Surface Inside Face Convection Heat Transfer Coefficient',
#     'schema:unitText': 'W/m2-K',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-inside-face-convection-heat-transfer-coefficient-wm2-k'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/W-PER-M2-K'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL002:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'dc:description': 'ZN001:WALL002:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL002:Surface Outside Face Convection Heat Transfer Coefficient',
#     'schema:unitText': 'W/m2-K',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-outside-face-convection-heat-transfer-coefficient-wm2-k'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/W-PER-M2-K'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL003:Surface Inside Face Temperature [C](Daily)',
#     'dc:description': 'ZN001:WALL003:Surface Inside Face Temperature [C](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL003:Surface Inside Face Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-inside-face-temperature-c'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL003:Surface Outside Face Temperature [C](Daily)',
#     'dc:description': 'ZN001:WALL003:Surface Outside Face Temperature [C](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL003:Surface Outside Face Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-outside-face-temperature-c'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL003:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'dc:description': 'ZN001:WALL003:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL003:Surface Inside Face Convection Heat Transfer Coefficient',
#     'schema:unitText': 'W/m2-K',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-inside-face-convection-heat-transfer-coefficient-wm2-k'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/W-PER-M2-K'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL003:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'dc:description': 'ZN001:WALL003:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL003:Surface Outside Face Convection Heat Transfer Coefficient',
#     'schema:unitText': 'W/m2-K',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-outside-face-convection-heat-transfer-coefficient-wm2-k'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/W-PER-M2-K'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL004:Surface Inside Face Temperature [C](Daily)',
#     'dc:description': 'ZN001:WALL004:Surface Inside Face Temperature [C](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL004:Surface Inside Face Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-inside-face-temperature-c'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL004:Surface Outside Face Temperature [C](Daily)',
#     'dc:description': 'ZN001:WALL004:Surface Outside Face Temperature [C](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL004:Surface Outside Face Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-outside-face-temperature-c'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL004:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'dc:description': 'ZN001:WALL004:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL004:Surface Inside Face Convection Heat Transfer Coefficient',
#     'schema:unitText': 'W/m2-K',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-inside-face-convection-heat-transfer-coefficient-wm2-k'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/W-PER-M2-K'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:WALL004:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'dc:description': 'ZN001:WALL004:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'schema:variableMeasured': 'ZN001:WALL004:Surface Outside Face Convection Heat Transfer Coefficient',
#     'schema:unitText': 'W/m2-K',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-outside-face-convection-heat-transfer-coefficient-wm2-k'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/W-PER-M2-K'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:FLR001:Surface Inside Face Temperature [C](Daily)',
#     'dc:description': 'ZN001:FLR001:Surface Inside Face Temperature [C](Daily)',
#     'schema:variableMeasured': 'ZN001:FLR001:Surface Inside Face Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-inside-face-temperature-c'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:FLR001:Surface Outside Face Temperature [C](Daily)',
#     'dc:description': 'ZN001:FLR001:Surface Outside Face Temperature [C](Daily)',
#     'schema:variableMeasured': 'ZN001:FLR001:Surface Outside Face Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-outside-face-temperature-c'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:FLR001:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'dc:description': 'ZN001:FLR001:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'schema:variableMeasured': 'ZN001:FLR001:Surface Inside Face Convection Heat Transfer Coefficient',
#     'schema:unitText': 'W/m2-K',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-inside-face-convection-heat-transfer-coefficient-wm2-k'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/W-PER-M2-K'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:ROOF001:Surface Inside Face Temperature [C](Daily)',
#     'dc:description': 'ZN001:ROOF001:Surface Inside Face Temperature [C](Daily)',
#     'schema:variableMeasured': 'ZN001:ROOF001:Surface Inside Face Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-inside-face-temperature-c'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:ROOF001:Surface Outside Face Temperature [C](Daily)',
#     'dc:description': 'ZN001:ROOF001:Surface Outside Face Temperature [C](Daily)',
#     'schema:variableMeasured': 'ZN001:ROOF001:Surface Outside Face Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-outside-face-temperature-c'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:ROOF001:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'dc:description': 'ZN001:ROOF001:Surface Inside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'schema:variableMeasured': 'ZN001:ROOF001:Surface Inside Face Convection Heat Transfer Coefficient',
#     'schema:unitText': 'W/m2-K',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-inside-face-convection-heat-transfer-coefficient-wm2-k'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/W-PER-M2-K'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZN001:ROOF001:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'dc:description': 'ZN001:ROOF001:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Daily)',
#     'schema:variableMeasured': 'ZN001:ROOF001:Surface Outside Face Convection Heat Transfer Coefficient',
#     'schema:unitText': 'W/m2-K',
#     'schema:duration': 'D1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#surface-outside-face-convection-heat-transfer-coefficient-wm2-k'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/W-PER-M2-K'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZONE ONE:Zone Mean Air Temperature [C](Hourly)',
#     'dc:description': 'ZONE ONE:Zone Mean Air Temperature [C](Hourly)',
#     'schema:variableMeasured': 'ZONE ONE:Zone Mean Air Temperature',
#     'schema:unitText': 'C',
#     'schema:duration': 'H1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#zone-mean-air-temperature-c-1'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/DEG_C'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZONE ONE:Zone Air Heat Balance Surface Convection Rate [W](Hourly)',
#     'dc:description': 'ZONE ONE:Zone Air Heat Balance Surface Convection Rate [W](Hourly)',
#     'schema:variableMeasured': 'ZONE ONE:Zone Air Heat Balance Surface Convection Rate',
#     'schema:unitText': 'W',
#     'schema:duration': 'H1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#zone-air-heat-balance-surface-convection-rate-w'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/W-PER-M'},
#     'datatype': 'number'},
#    {'@type': 'Column',
#     'titles': 'ZONE ONE:Zone Air Heat Balance Air Energy Storage Rate [W](Hourly)',
#     'dc:description': 'ZONE ONE:Zone Air Heat Balance Air Energy Storage Rate [W](Hourly)',
#     'schema:variableMeasured': 'ZONE ONE:Zone Air Heat Balance Air Energy Storage Rate',
#     'schema:unitText': 'W',
#     'schema:duration': 'H1',
#     'dc:references': {'@id': 'https://bigladdersoftware.com/epx/docs/9-6/input-output-reference/group-thermal-zone-description-geometry.html#zone-air-heat-balance-air-energy-storage-rate-w'},
#     'http://purl.org/linked-data/sdmx/2009/attribute#unitMeasure': {'@id': 'http://qudt.org/vocab/unit/W-PER-M'},
#     'datatype': 'number'}]}}
